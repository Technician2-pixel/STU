# %%
num1_input = input("Enter first number: ")   
operator = input("Enter operator (+, -, *, /, //, %, **): ")
num2_input = input("Enter second number: ") 


num1 = float(num1_input)
num2 = float(num2_input)

result = None
error_message = None

if operator == "+":
    result = num1 + num2
elif operator == "-":
    result = num1 - num2
elif operator == "*":
    result = num1 * num2
elif operator == "/":
    if num2 == 0:
        error_message = "Error: Division by zero is not allowed."
    else:
        result = num1 / num2
elif operator == "//":
    if num2 == 0:
        error_message = "Error: Division by zero is not allowed."
    else:
        result = num1 // num2
elif operator == "%":
    if num2 == 0:
        error_message = "Error: Modulo by zero is not allowed."
    else:
        result = num1 % num2
elif operator == "**":
    result = num1 ** num2
else:
    error_message = "Error: Invalid operator."

    print("\n===== SIMPLE CALCULATOR =====")
if error_message:
    print(error_message)
else:
    if operator == "/":
        print(f"Result: {num1} {operator} {num2} = {result:.4f}")
    else:
        print(f"Result: {num1} {operator} {num2} = {result}")


    if result > 0:
        print("The result is positive.")
    elif result < 0:
        print("The result is negative.")
    else:
        print("The result is zero.")
print("===================")

print("=======TYPE DEMONSTRATION ========")
print(f"Original num1 input type: {type(num1_input)}  Converted type: {type(num1)}")
print(f"Original num2 input type: {type(num2_input)}  Converted type: {type(num2)}")
# Out:
# Enter first number:  45
# Enter operator (+, -, *, /, //, %, **):  *
# Enter second number:  45
# Result: 45.0 * 45.0 = 2025.0
# The result is positive.
# ...
# =======TYPE DEMONSTRATION ========
# Original num1 input type: <class 'str'>  Converted type: <class 'float'>
# Original num2 input type: <class 'str'>  Converted type: <class 'float'>
